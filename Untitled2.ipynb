# %%
import xml.etree.ElementTree as ET

# Specify the XML file path
xml_file_path = r"C:\Users\monab\Downloads\online gait course july 2023 edits-20230714T154046Z-001\online gait course july 2023 edits\NSERC project work\data\session_data.xml"

# Parse the XML file
tree = ET.parse(xml_file_path)
root = tree.getroot()

#trial 1

# Find the desired element
target_element = root.find(".//owner[@value='Cutting Left 1.c3d']/type[@value='LINK_MODEL_BASED']/folder[@value='ORIGINAL']/name[@value='Left Knee Angles']")

# Extract the X component data
x_data = target_element.find("./component[@value='X']").attrib['data']

# Split the data string into a list of values
x_values = x_data.split(',')

# Save the X values into a variable
Knee_Flexion_Trial1_LT = x_values

# Print the X values
print("Knee_Flexion_Trial1_LT")
for value in x_values:
    print(value)

#trial 2

# Find the desired element
target_element = root.find(".//owner[@value='Cutting Left 2.c3d']/type[@value='LINK_MODEL_BASED']/folder[@value='ORIGINAL']/name[@value='Left Knee Angles']")

# Extract the X component data
x_data = target_element.find("./component[@value='X']").attrib['data']

# Split the data string into a list of values
x_values = x_data.split(',')

# Save the X values into a variable
Knee_Flexion_Trial2_LT = x_values

# Print the X values
print("Knee_Flexion_Trial2_LT")
for value in x_values:
    print(value)
# Out:
# Knee_Flexion_Trial1_LT
# 1.103913e+02
# 1.077508e+02
# 1.047965e+02
# 1.015079e+02
# 9.786809e+01
# 9.386750e+01
# 8.950514e+01
# 8.478881e+01
# 7.973732e+01
# 7.438544e+01
# 6.878969e+01
# 6.303183e+01
# 5.721677e+01
# 5.146575e+01
# 4.590814e+01
# 4.067576e+01
# 3.590005e+01
# 3.170934e+01
# 2.822289e+01
# 2.554101e+01
# 2.373606e+01
# 2.284915e+01
# 2.289314e+01
# 2.385716e+01
# 2.570689e+01
# 2.837643e+01
# 3.175614e+01
# 3.568351e+01
# 3.994054e+01
# 4.426329e+01
# 4.837526e+01
# 5.204226e+01
# 5.512120e+01
# 5.757348e+01
# 5.944387e+01
# 6.082400e+01
# 6.181988e+01
# 6.253225e+01
# 6.304634e+01
# 6.342708e+01
# 6.371727e+01
# 6.393895e+01
# 6.409653e+01
# 6.418111e+01
# 6.417484e+01
# 6.405389e+01
# 6.379059e+01
# 6.335533e+01
# 6.271754e+01
# 6.184493e+01
# 6.070240e+01
# 5.925220e+01
# 5.745632e+01
# 5.527996e+01
# 5.269613e+01
# 4.969164e+01
# 4.627481e+01
# 4.248449e+01
# 3.839855e+01
# 3.414036e+01
# 2.987996e+01
# 2.582565e+01
# 2.220154e+01
# 1.921490e+01
# 1.702469e+01
# 1.572409e+01
# 1.534232e+01
# 1.586395e+01
# 1.725479e+01
# 1.947960e+01
# 2.249916e+01
# 2.624826e+01
# 3.061028e+01
# 3.540719e+01
# 4.041682e+01
# 4.540796e+01
# 5.017036e+01
# 5.452608e+01
# 5.832953e+01
# 6.147566e+01
# Knee_Flexion_Trial2_LT
# 8.365003e+01
# 7.888814e+01
# 7.377225e+01
# 6.842686e+01
# 6.296801e+01
# 5.749971e+01
# 5.211758e+01
# 4.691485e+01
# 4.198738e+01
# 3.743488e+01
# 3.335778e+01
# 2.985095e+01
# 2.699576e+01
# 2.485358e+01
# 2.346332e+01
# 2.284461e+01
# 2.300511e+01
# 2.394715e+01
# 2.566615e+01
# 2.813701e+01
# 3.129548e+01
# 3.502467e+01
# 3.914851e+01
# 4.343421e+01
# 4.761673e+01
# 5.145228e+01
# 5.477805e+01
# 5.754010e+01
# 5.977604e+01
# 6.157364e+01
# 6.303174e+01
# 6.423685e+01
# 6.525352e+01
# 6.612218e+01
# 6.686088e+01
# 6.746928e+01
# 6.793415e+01
# 6.823518e+01
# 6.834995e+01
# 6.825675e+01
# 6.793563e+01
# 6.736757e+01
# 6.653344e+01
# 6.541325e+01
# 6.398638e+01
# 6.223263e+01
# 6.013433e+01
# 5.767965e+01
# 5.486648e+01
# 5.170814e+01
# 4.824047e+01
# 4.453042e+01
# 4.068262e+01
# 3.684061e+01
# 3.317922e+01
# 2.988483e+01
# 2.712650e+01
# 2.502847e+01
# 2.365581e+01
# 2.301788e+01
# 2.308684e+01
# 2.382237e+01
# 2.519143e+01
# 2.717328e+01
# 2.974836e+01
# 3.287841e+01
# 3.649191e+01
# 4.048634e+01
# 4.474791e+01
# 4.917702e+01
# 5.370371e+01
# 5.828709e+01
# 6.290298e+01
# 6.752956e+01
# 7.213633e+01
# 7.667871e+01
# 8.109624e+01
# 8.531359e+01
# 8.924476e+01
# 9.280093e+01
# 9.590495e+01
# 9.851016e+01
